ics.smartphone</td><td>1081.98</td></tr><tr><td>computers.desktop</td><td>computers.desktop</td><td>908.62</td></tr><tr><td>null</td><td>null</td><td>380.96</td></tr><tr><td>null</td><td>null</td><td>41.16</td></tr><tr><td>apparel.shoes.keds</td><td>apparel.shoes.keds</td><td>102.71</td></tr><tr><td>electronics.smartphone</td><td>electronics.smartphone</td><td>566.01</td></tr></tbody></table></div>

# %%
filtered_df = selected_df.filter(col("Price") > 300)
display(filtered_df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category_code</th><th>category_code</th><th>price</th></tr></thead><tbody><tr><td>furniture.living_room.sofa</td><td>furniture.living_room.sofa</td><td>543.1</td></tr><tr><td>electronics.smartphone</td><td>electronics.smartphone</td><td>1081.98</td></tr><tr><td>computers.desktop</td><td>computers.desktop</td><td>908.62</td></tr><tr><td>null</td><td>null</td><td>380.96</td></tr><tr><td>electronics.smartphone</td><td>electronics.smartphone</td><td>566.01</td></tr><tr><td>electronics.smartphone</td><td>electronics.smartphone</td><td>900.64</td></tr><tr><td>null</td><td>null</td><td>357.79</td></tr><tr><td>computers.notebook</td><td>computers.notebook</td><td>580.89</td></tr><tr><td>electronics.smartphone</td><td>electronics.smartphone</td><td>1747.79</td></tr><tr><td>electronics.smartphone</td><td>electronics.smartphone</td><td>588.77</td></tr></tbody></table></div>

# %%
grouped_df = filtered_df.groupBy("category_code").count()
display(grouped_df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category_code</th><th>count</th></tr></thead><tbody><tr><td>stationery.cartrige</td><td>57</td></tr><tr><td>electronics.video.tv</td><td>681607</td></tr><tr><td>accessories.wallet</td><td>913</td></tr><tr><td>appliances.kitchen.juicer</td><td>1221</td></tr><tr><td>null</td><td>2304264</td></tr><tr><td>construction.tools.welding</td><td>20662</td></tr><tr><td>appliances.environment.air_heater</td><td>1716</td></tr><tr><td>apparel.shoes</td><td>707</td></tr><tr><td>electronics.audio.microphone</td><td>2565</td></tr><tr><td>appliances.kitchen.dishwasher</td><td>68221</td></tr></tbody></table></div>

# %%
final_df = grouped_df.orderBy(desc("count"))
final_df.show()
# Out:
# +--------------------+-------+
# |       category_code|  count|
# +--------------------+-------+
# |electronics.smart...|5476179|
# |                NULL|2304264|
# |  computers.notebook| 966633|
# |electronics.video.tv| 681607|
# |appliances.kitche...| 454152|
# |  electronics.clocks| 427896|
# |appliances.kitche...| 416725|
# |   computers.desktop| 246491|
# |furniture.living_...| 201485|
# |appliances.enviro...| 125096|
# |  electronics.tablet| 113853|
# |furniture.living_...|  85996|
# |appliances.kitche...|  68221|
# |furniture.bedroom...|  56569|
# |         kids.skates|  52058|
# |appliances.kitche...|  50300|
# |       sport.bicycle|  45840|
# |       kids.carriage|  42512|
# |auto.accessories....|  37571|
# |electronics.audio...|  35328|
# +--------------------+-------+
# only showing top 20 rows

# %%
final_df.write.format("csv") \
    .mode("overwrite") \
    .option("header", "true") \
    .save("/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct_Processed_Product_Centric_Result.csv")

print("Export Complete!")
# Out:
# Export Complete!
